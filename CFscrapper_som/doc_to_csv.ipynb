# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
import spacy
nlp=spacy.load('/opt/homebrew/lib/python3.11/site-packages/en_core_web_sm/en_core_web_sm-3.5.0')

# %%
file=open('96-A','r')
content=file.read()

# %%
print(content)
# Out:
# #include <iostream>
# using namespace std;
#
#
# int main(){
#      string s;
#      cin>>s;
#      int a=s.length();
#      int count=0;
#      for(int i=0; i<(a-1);i++){
#         if(s[i]==s[i+1]){
#             count++;
#         }
#         if(s[i]!=s[i+1]){
#             count=0;
#         }
#         if(count>=6){
#             cout<<"YES"<<endl;
#             break;
#         }
#      }
#
#      if(count<6){
#         cout<<"NO"<<endl;
#      }
#
# return 0;
# }

# %%
yo=nlp(content)

# %%
for token in yo:
    print(token.text)
# Out:
# #
# include
# <
# iostream
# >
#
#
# using
# namespace
# std
# ;
#
#
#
#
# int
# main
# (
# )
# {
#
#
# string
# s
# ;
#
#
# cin>>s
# ;
#
#
# int
# a
# =
# s.length
# (
# )
# ;
#
#
# int
# count=0
# ;
#
#
# for(int
# i=0
# ;
# i<(a-1);i++
# )
# {
#
#
# if(s[i]==s[i+1
# ]
# )
# {
#
#
# count++
# ;
#
#
# }
#
#
# if(s[i]!=s[i+1
# ]
# )
# {
#
#
# count=0
# ;
#
#
# }
#
#
# if(count>=6
# )
# {
#
#
# cout<<"YES"<<endl
# ;
#
#
# break
# ;
#
#
# }
#
#
# }
#
#
#
# if(count<6
# )
# {
#
#
# cout<<"NO"<<endl
# ;
#
#
# }
#
#
#
# return
# 0
# ;
#
#
# }

# %%
segmented=content.split('\n')

# %%
new=np.array(segmented)

# %%
print(new)
# Out:
# ['#include <iostream>' 'using namespace std; ' ' ' ' ' 'int main(){ '
#  '     string s;' '     cin>>s;' '     int a=s.length();'
#  '     int count=0;' '     for(int i=0; i<(a-1);i++){'
#  '        if(s[i]==s[i+1]){' '            count++;' '        }'
#  '        if(s[i]!=s[i+1]){' '            count=0;' '        }'
#  '        if(count>=6){' '            cout<<"YES"<<endl;'
#  '            break;' '        }' '     }' ' ' '     if(count<6){'
#  '        cout<<"NO"<<endl;' '     }' ' ' 'return 0;' '}']

# %%
dframe=pd.DataFrame(new)

# %%
dframe
# Out:
#                                   0
# 0               #include <iostream>
# 1             using namespace std;
# 2
# 3
# 4                      int main(){
# 5                         string s;
# 6                           cin>>s;
# 7                 int a=s.length();
# 8                      int count=0;
# 9        for(int i=0; i<(a-1);i++){
# 10                if(s[i]==s[i+1]){
# 11                         count++;
# 12                                }
# 13                if(s[i]!=s[i+1]){
# 14                         count=0;
# 15                                }
# 16                    if(count>=6){
# 17               cout<<"YES"<<endl;
# 18                           break;
# 19                                }
# 20                                }
# 21
# 22                     if(count<6){
# 23                cout<<"NO"<<endl;
# 24                                }
# 25
# 26                        return 0;
# 27                                }

# %%
dframe.loc[20,0]
# Out:
# '     }'

# %%
newdf=(dframe[0]==' ')|(dframe[0]=='}')|(dframe[0]=='     }')|(dframe[0]=='        }')

# %%
newdf
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26    False
# 27     True
# Name: 0, dtype: bool

# %%
dframe.drop(index=dframe[newdf].index, inplace=True)

# %%
dframe
# Out:
#                                   0
# 0               #include <iostream>
# 1             using namespace std;
# 4                      int main(){
# 5                         string s;
# 6                           cin>>s;
# 7                 int a=s.length();
# 8                      int count=0;
# 9        for(int i=0; i<(a-1);i++){
# 10                if(s[i]==s[i+1]){
# 11                         count++;
# 13                if(s[i]!=s[i+1]){
# 14                         count=0;
# 16                    if(count>=6){
# 17               cout<<"YES"<<endl;
# 18                           break;
# 22                     if(count<6){
# 23                cout<<"NO"<<endl;
# 26                        return 0;
